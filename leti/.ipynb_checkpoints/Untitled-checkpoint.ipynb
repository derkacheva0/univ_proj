# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mark = pd.read_csv('new_marks.csv')
mark
# Out:
#         КодОбучения  НомерЛД ПерваяПопытка Итог  Пересдавал  Семестр  \
# 0             31127    10019           Отл  Отл           0        1
# 1             31127    10019           Хор  Хор           0        1
# 2             31127    10019           Удв  Удв           0        1
# 3             31127    10019           Хор  Хор           0        1
# 4             31127    10019           Хор  Хор           0        1
# ...             ...      ...           ...  ...         ...      ...
# 172196        48290  9990323           Н/я  Н/я           0        1
# 172197        48290  9990323           Н/я  Н/я           0        1
# 172198        48290  9990323           Н/я  Н/я           0        1
# 172199        48290  9990323           Н/я  Н/я           0        1
# 172200        48290  9990323           Н/я  Н/я           0        1
#
#                                                Дисциплина  КодПланыСтроки  \
# 0       Оптимизирующее проектирование вычислительной т...       2091027.0
# 1                             Цифровая обработка сигналов       2091013.0
# 2                          Безопасность жизнедеятельности       2090998.0
# 3                      Введение в искусственный интеллект       2091014.0
# 4                      Введение в искусственный интеллект       2091014.0
# ...                                                   ...             ...
# 172196                                   Иностранный язык       2098349.0
# 172197  Зачет с оценкой по дисциплине "Основы российск...       2106761.0
# 172198                                 Инженерная графика       2098368.0
# 172199                                Алгебра и геометрия       2098351.0
# 172200                                 Инженерная графика       2098368.0
#
#          Кафедра             Тип_Ведомости        Год
# 0         каф.ВТ                   Экзамен  2023-2024
# 1         каф.ВТ  Дифференцированный зачет  2023-2024
# 2        каф.БЖД  Дифференцированный зачет  2023-2024
# 3         каф.ВТ                   Экзамен  2023-2024
# 4         каф.ВТ                  К/работа  2023-2024
# ...          ...                       ...        ...
# 172196  каф.ИНЯЗ  Дифференцированный зачет  2023-2024
# 172197  каф.ИКГП  Дифференцированный зачет  2023-2024
# 172198  каф.ПМИГ  Дифференцированный зачет  2023-2024
# 172199    каф.АМ                   Экзамен  2023-2024
# 172200  каф.ПМИГ                  К/работа  2023-2024
#
# [172201 rows x 11 columns]

# %%
mark = mark[['НомерЛД', 'ПерваяПопытка', 'Семестр', 'Дисциплина', 'Кафедра', 'Тип_Ведомости']]

# %%
visits = pd.read_csv('visits.csv')
visits
# Out:
#          ID ЛК  ID Предмета  \
# 0          213           51
# 1          213           59
# 2          213           60
# 3          213           78
# 4          213          210
# ...        ...          ...
# 453913  424749         4937
# 453914  424749         5074
# 453915  424749         6327
# 453916  424758         5863
# 453917  424758         6125
#
#                                                     title   Сезон   Год  \
# 0       Компьютерные технологии и моделирование в элек...  autumn  2023
# 1       Современные проблемы электроники (Problems of ...  autumn  2023
# 2       Современные проблемы электроники (Problems of ...  autumn  2023
# 3       Русский язык как иностранный (Russian as a For...  autumn  2023
# 4       Основы научных исследований (Foundations of Sc...  autumn  2023
# ...                                                   ...     ...   ...
# 453913                              Экономика организации  autumn  2024
# 453914                                        Физкультура  autumn  2024
# 453915                Теоретические основы электротехники  autumn  2024
# 453916  Коммерциализация результатов научных исследова...  autumn  2024
# 453917                          Военно-морская подготовка  autumn  2024
#
#         Всего занятий  Посещений (студ.)  Посещений (стар.)  Отметок (стар.)  \
# 0                  16                 10                 10               10
# 1                  18                  2                  2               10
# 2                  16                  2                  2               12
# 3                   2                  2                  0                0
# 4                  18                  2                  2               12
# ...               ...                ...                ...              ...
# 453913              1                  0                  1                1
# 453914              1                  0                  1                1
# 453915              1                  0                  0                1
# 453916              1                  0                  0                0
# 453917              1                  0                  0                0
#
#         Посещений (преп.)  Отметок (преп.)  Посещений (СКУД)  Отметок (СКУД)
# 0                      10               10                12              16
# 1                       0                4                 2              16
# 2                       0                0                 2              16
# 3                       0                0                 2               2
# 4                       2               10                 2              16
# ...                   ...              ...               ...             ...
# 453913                  0                0                 0               0
# 453914                  0                0                 0               0
# 453915                  0                1                 0               0
# 453916                  0                0                 0               0
# 453917                  0                0                 0               0
#
# [453918 rows x 13 columns]

# %%
visits['Год'].unique()
# Out:
# array([2023, 2024], dtype=int64)

# %%
visits = visits[['ID ЛК', 'title', 'Сезон', 'Год', 'Посещений (СКУД)', 'Отметок (СКУД)']]

# %%
visits['visit'] = (visits['Посещений (СКУД)'] / visits['Отметок (СКУД)']).fillna(0)
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\3630138299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visits['visit'] = (visits['Посещений (СКУД)'] / visits['Отметок (СКУД)']).fillna(0)

# %%
visits = visits[['ID ЛК', 'title', 'Сезон', 'Год', 'visit']]

# %%
st = pd.read_csv('students.csv')
st
# Out:
#        ID ИОТ   ID ЛК          ДР  ID Обучения (ЛК)  КодОбучения (Шахты)  \
# 0       23929  424241         NaN             41530                  NaN
# 1        1305    2340   1998-8-14             33827              44035.0
# 2        1308    9870   1999-7-10             37817              48052.0
# 3        1317    2313    1999-2-8             33828              44036.0
# 4        1319    2314    1999-3-4             33843              44059.0
# ...       ...     ...         ...               ...                  ...
# 18625   20066     215   1989-2-18             18196              27673.0
# 18626   20067     697   1998-7-17               501                  NaN
# 18627   20095  323653   1989-5-15             19098              28569.0
# 18628   20097  374093  2001-12-11             20312                  NaN
# 18629   23564    4829   1997-4-20              4648              16237.0
#
#        Зачетка  НомерЛД (Шахты)  Иностранец  ID Группы  Группа  Курс  \
# 0        59811           305524       False      23672     598     1
# 1       293504          4090316       False      22415    2935     2
# 2       393507          2220317       False      22416    3935     1
# 3       293702          3440316       False      22355    2937     2
# 4       293703          1080316       False      22355    2937     2
# ...        ...              ...         ...        ...     ...   ...
# 18625   430007          6680412        True      18042    4300     2
# 18626   639202          4960316       False      18036    6392     4
# 18627   430012           585318        True      18042    4300     2
# 18628   920409          1540219       False      18296    9204     1
# 18629   618227           150115       False      17899    6182     4
#
#       Учебный год Срок обучения         Статус  Статус.1 Гражданство  \
# 0       2024-2025             2            NaN       NaN         NaN
# 1       2023-2024             3         Бюджет  Учащийся          РФ
# 2       2023-2024             3         Бюджет  Учащийся          РФ
# 3       2023-2024             3         Бюджет  Учащийся          РФ
# 4       2023-2024             3         Бюджет  Учащийся          РФ
# ...           ...           ...            ...       ...         ...
# 18625   2019-2020             2       Контракт  Закончил        Гана
# 18626   2019-2020             4  Целевой прием  Закончил          РФ
# 18627   2019-2020             2       Контракт  Закончил      Египет
# 18628   2019-2020             4         Бюджет  Отчислен          РФ
# 18629   2019-2020             4         Бюджет  Закончил          РФ
#
#       Шифр специальность                                    Специальность  \
# 0               20.04.01                        Техносферная безопасность
# 1                    2.3     Информационные технологии и телекоммуникации
# 2                    2.3     Информационные технологии и телекоммуникации
# 3                    1.2                 Компьютерные науки и информатика
# 4                    1.2                 Компьютерные науки и информатика
# ...                  ...                                              ...
# 18625           09.04.01             Информатика и вычислительная техника
# 18626           27.03.04                Управление в технических системах
# 18627           09.04.01             Информатика и вычислительная техника
# 18628           11.03.04                    Электроника и наноэлектроника
# 18629           11.03.02  Инфокоммуникационные технологии и системы связи
#
#       Уровень образования Форма образования
# 0            Магистратура       Очная форма
# 1             Аспирантура       Очная форма
# 2             Аспирантура       Очная форма
# 3             Аспирантура       Очная форма
# 4             Аспирантура       Очная форма
# ...                   ...               ...
# 18625        Магистратура       Очная форма
# 18626         Бакалавриат       Очная форма
# 18627        Магистратура       Очная форма
# 18628         Бакалавриат       Очная форма
# 18629         Бакалавриат       Очная форма
#
# [18630 rows x 20 columns]

# %%
st = st[['ID ЛК', 'НомерЛД (Шахты)', 'Иностранец', 'Курс', 'Статус', 'Статус.1', 'Уровень образования', 'Форма образования']]

# %% [markdown]
# параметры модели
# - номер студента (уникальный id),
# - финансирование (платная основа/бюджетная),
# - статус (учащийся, отчислен, академический отпуск),
# - форма образования (очная, очно-заочная, заочная),
# - процент посещения занятий,
# - тип ведомости (экзамен, дифференцированный зачет, курсовая, практика)
# - кафедра, на которой преподается предмет

# %%
mark.head(3)
# Out:
#    НомерЛД ПерваяПопытка  Семестр  \
# 0    10019           Отл        1
# 1    10019           Хор        1
# 2    10019           Удв        1
#
#                                           Дисциплина  Кафедра  \
# 0  Оптимизирующее проектирование вычислительной т...   каф.ВТ
# 1                        Цифровая обработка сигналов   каф.ВТ
# 2                     Безопасность жизнедеятельности  каф.БЖД
#
#               Тип_Ведомости
# 0                   Экзамен
# 1  Дифференцированный зачет
# 2  Дифференцированный зачет

# %%
mark['ПерваяПопытка'] = mark['ПерваяПопытка'].map({'Отл': 5,
                           'Хор': 4, 
                           'Удв': 3, 
                           'Н/я': 2, 
                           'Зач': 5, 
                           'Неуд': 2, 
                           'Н/з': 2})
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\4218606137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mark['ПерваяПопытка'] = mark['ПерваяПопытка'].map({'Отл': 5,

# %%
mark
# Out:
#         НомерЛД  ПерваяПопытка  Семестр  \
# 0         10019              5        1
# 1         10019              4        1
# 2         10019              3        1
# 3         10019              4        1
# 4         10019              4        1
# ...         ...            ...      ...
# 172196  9990323              2        1
# 172197  9990323              2        1
# 172198  9990323              2        1
# 172199  9990323              2        1
# 172200  9990323              2        1
#
#                                                Дисциплина   Кафедра  \
# 0       Оптимизирующее проектирование вычислительной т...    каф.ВТ
# 1                             Цифровая обработка сигналов    каф.ВТ
# 2                          Безопасность жизнедеятельности   каф.БЖД
# 3                      Введение в искусственный интеллект    каф.ВТ
# 4                      Введение в искусственный интеллект    каф.ВТ
# ...                                                   ...       ...
# 172196                                   Иностранный язык  каф.ИНЯЗ
# 172197  Зачет с оценкой по дисциплине "Основы российск...  каф.ИКГП
# 172198                                 Инженерная графика  каф.ПМИГ
# 172199                                Алгебра и геометрия    каф.АМ
# 172200                                 Инженерная графика  каф.ПМИГ
#
#                    Тип_Ведомости
# 0                        Экзамен
# 1       Дифференцированный зачет
# 2       Дифференцированный зачет
# 3                        Экзамен
# 4                       К/работа
# ...                          ...
# 172196  Дифференцированный зачет
# 172197  Дифференцированный зачет
# 172198  Дифференцированный зачет
# 172199                   Экзамен
# 172200                  К/работа
#
# [172201 rows x 6 columns]

# %%
mark.to_csv('marks.csv', index=False, encoding='utf-8')

# %%
visits['visit'] = visits['visit'] * 100
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\1156169901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visits['visit'] = visits['visit'] * 100

# %%
visits.rename(columns={'title': 'Дисциплина'}, inplace=True)
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\3703320295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visits.rename(columns={'title': 'Дисциплина'}, inplace=True)

# %%
visits.head(3)
# Out:
#    ID ЛК                                         Дисциплина   Сезон   Год  \
# 0    213  Компьютерные технологии и моделирование в элек...  autumn  2023
# 1    213  Современные проблемы электроники (Problems of ...  autumn  2023
# 2    213  Современные проблемы электроники (Problems of ...  autumn  2023
#
#    visit
# 0   75.0
# 1   12.5
# 2   12.5

# %%
visits.to_csv('visits_coef.csv', index=False, encoding='utf-8')

# %%
st.rename(columns={'Статус': 'finans', 'Статус.1': 'status'}, inplace=True)
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\1332313240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st.rename(columns={'Статус': 'finans', 'Статус.1': 'status'}, inplace=True)

# %%
st.rename(columns={'НомерЛД (Шахты)': 'НомерЛД'}, inplace=True)
# Out:
# C:\Users\romas\AppData\Local\Temp\ipykernel_9260\1072524807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st.rename(columns={'НомерЛД (Шахты)': 'НомерЛД'}, inplace=True)

# %%
st.head(3)
# Out:
#     ID ЛК  НомерЛД  Иностранец  Курс  finans    status Уровень образования  \
# 0  424241   305524       False     1     NaN       NaN        Магистратура
# 1    2340  4090316       False     2  Бюджет  Учащийся         Аспирантура
# 2    9870  2220317       False     1  Бюджет  Учащийся         Аспирантура
#
#   Форма образования
# 0       Очная форма
# 1       Очная форма
# 2       Очная форма

# %%
st.to_csv('student.csv', index=False, encoding='utf-8')

# %% [markdown]
# ----

# %% [markdown]
# ## Объединение таблиц

# %%
mark.head()
# Out:
#    НомерЛД  ПерваяПопытка  Семестр  \
# 0    10019              5        1
# 1    10019              4        1
# 2    10019              3        1
# 3    10019              4        1
# 4    10019              4        1
#
#                                           Дисциплина  Кафедра  \
# 0  Оптимизирующее проектирование вычислительной т...   каф.ВТ
# 1                        Цифровая обработка сигналов   каф.ВТ
# 2                     Безопасность жизнедеятельности  каф.БЖД
# 3                 Введение в искусственный интеллект   каф.ВТ
# 4                 Введение в искусственный интеллект   каф.ВТ
#
#               Тип_Ведомости
# 0                   Экзамен
# 1  Дифференцированный зачет
# 2  Дифференцированный зачет
# 3                   Экзамен
# 4                  К/работа

# %%
st.head()
# Out:
#     ID ЛК  НомерЛД  Иностранец  Курс  finans    status Уровень образования  \
# 0  424241   305524       False     1     NaN       NaN        Магистратура
# 1    2340  4090316       False     2  Бюджет  Учащийся         Аспирантура
# 2    9870  2220317       False     1  Бюджет  Учащийся         Аспирантура
# 3    2313  3440316       False     2  Бюджет  Учащийся         Аспирантура
# 4    2314  1080316       False     2  Бюджет  Учащийся         Аспирантура
#
#   Форма образования
# 0       Очная форма
# 1       Очная форма
# 2       Очная форма
# 3       Очная форма
# 4       Очная форма

# %%
st_mark = pd.merge(mark, st, how='left', on='НомерЛД')

# %%
st_mark.head(3)
# Out:
#    НомерЛД  ПерваяПопытка  Семестр  \
# 0    10019              5        1
# 1    10019              4        1
# 2    10019              3        1
#
#                                           Дисциплина  Кафедра  \
# 0  Оптимизирующее проектирование вычислительной т...   каф.ВТ
# 1                        Цифровая обработка сигналов   каф.ВТ
# 2                     Безопасность жизнедеятельности  каф.БЖД
#
#               Тип_Ведомости     ID ЛК Иностранец  Курс    finans    status  \
# 0                   Экзамен  375051.0      False   5.0  Контракт  Учащийся
# 1  Дифференцированный зачет  375051.0      False   5.0  Контракт  Учащийся
# 2  Дифференцированный зачет  375051.0      False   5.0  Контракт  Учащийся
#
#   Уровень образования Форма образования
# 0         Бакалавриат     Заочная форма
# 1         Бакалавриат     Заочная форма
# 2         Бакалавриат     Заочная форма

# %%
visits.head(3)
# Out:
#    ID ЛК                                         Дисциплина   Сезон   Год  \
# 0    213  Компьютерные технологии и моделирование в элек...  autumn  2023
# 1    213  Современные проблемы электроники (Problems of ...  autumn  2023
# 2    213  Современные проблемы электроники (Problems of ...  autumn  2023
#
#    visit
# 0   75.0
# 1   12.5
# 2   12.5

# %%
#df = pd.merge(st_mark, visits, how='left', on=['ID ЛК', 'Дисциплина'])

visits_2023 = visits[visits['Год'] == 2023]
visits_2024 = visits[visits['Год'] == 2024]

merged_odd = pd.merge(st_mark[st_mark['Семестр'] % 2 != 0], visits_2023, how='inner', on=['ID ЛК', 'Дисциплина'])
merged_even = pd.merge(st_mark[st_mark['Семестр'] % 2 == 0], visits_2024, how='inner', on=['ID ЛК', 'Дисциплина'])

df = pd.concat([merged_odd, merged_even], ignore_index=True)

# %%
visits[visits['ID ЛК'] == 375210.0]
# Out:
#         ID ЛК                                         Дисциплина   Сезон  \
# 31941  375210               Радиоэлектронные системы и комплексы  autumn
# 31942  375210               Радиоэлектронные системы и комплексы  autumn
# 31943  375210                         Функциональная электроника  autumn
# 31944  375210  Основы автоматизированного проектирования анте...  autumn
# 31945  375210  Основы автоматизированного проектирования анте...  autumn
# 31946  375210  Основы автоматизированного проектирования анте...  autumn
# 31947  375210                     Устройства сверхвысоких частот  autumn
# 31948  375210            Оптическая связь и обработка информации  autumn
# 31949  375210                     Устройства сверхвысоких частот  autumn
# 31950  375210                         Функциональная электроника  autumn
# 31951  375210            Оптическая связь и обработка информации  autumn
# 31952  375210                          Военно-морская подготовка  autumn
# 31953  375210  Цифровая обработка пространственно-временных с...  spring
# 31954  375210  Цифровая обработка пространственно-временных с...  spring
# 31955  375210  Цифровая обработка пространственно-временных с...  spring
# 31956  375210  Методы машинного обучения в цифровой обработке...  spring
# 31957  375210  Методы машинного обучения в цифровой обработке...  spring
# 31958  375210                              Микроволновая техника  spring
# 31959  375210                              Микроволновая техника  spring
# 31960  375210                        Антенны сверхвысоких частот  spring
# 31961  375210                        Антенны сверхвысоких частот  spring
# 31962  375210                        Антенны сверхвысоких частот  spring
# 31963  375210                          Военно-морская подготовка  spring
#
#         Год      visit
# 31941  2023  50.000000
# 31942  2023  33.333333
# 31943  2023  43.750000
# 31944  2023  50.000000
# 31945  2023  31.250000
# 31946  2023  88.888889
# 31947  2023  25.000000
# 31948  2023  88.888889
# 31949  2023  25.000000
# 31950  2023   0.000000
# 31951  2023  16.000000
# 31952  2023   0.000000
# 31953  2024  57.142857
# 31954  2024  57.142857
# 31955  2024  28.571429
# 31956  2024  66.666667
# 31957  2024  30.000000
# 31958  2024  21.428571
# 31959  2024  78.571429
# 31960  2024   0.000000
# 31961  2024  37.500000
# 31962  2024  50.000000
# 31963  2024   0.000000

# %%
df
# Out:
#         НомерЛД  ПерваяПопытка  Семестр  \
# 0         10119              4        9
# 1         10119              4        9
# 2         10119              2        9
# 3         10119              2        9
# 4         10119              2        9
# ...         ...            ...      ...
# 286621  9960323              3        2
# 286622  9960323              3        2
# 286623  9960323              3        2
# 286624  9960323              2        2
# 286625  9960323              2        2
#
#                                                Дисциплина     Кафедра  \
# 0                 Оптическая связь и обработка информации     каф.ТОР
# 1                 Оптическая связь и обработка информации     каф.ТОР
# 2       Основы автоматизированного проектирования анте...     каф.ТОР
# 3       Основы автоматизированного проектирования анте...     каф.ТОР
# 4       Основы автоматизированного проектирования анте...     каф.ТОР
# ...                                                   ...         ...
# 286621                                             Физика  каф.Физики
# 286622                                             Физика  каф.Физики
# 286623                                             Физика  каф.Физики
# 286624                              Математический анализ      каф.АМ
# 286625                              Математический анализ      каф.АМ
#
#                    Тип_Ведомости     ID ЛК Иностранец  Курс    finans  \
# 0       Дифференцированный зачет  375210.0       True   5.0    Бюджет
# 1       Дифференцированный зачет  375210.0       True   5.0    Бюджет
# 2                        Экзамен  375210.0       True   5.0    Бюджет
# 3                        Экзамен  375210.0       True   5.0    Бюджет
# 4                        Экзамен  375210.0       True   5.0    Бюджет
# ...                          ...       ...        ...   ...       ...
# 286621                   Экзамен  419081.0      False   1.0  Контракт
# 286622                   Экзамен  419081.0      False   1.0  Контракт
# 286623                   Экзамен  419081.0      False   1.0  Контракт
# 286624                   Экзамен  419081.0      False   1.0  Контракт
# 286625                   Экзамен  419081.0      False   1.0  Контракт
#
#           status Уровень образования Форма образования   Сезон   Год  \
# 0       Учащийся         Специалитет       Очная форма  autumn  2023
# 1       Учащийся         Специалитет       Очная форма  autumn  2023
# 2       Учащийся         Специалитет       Очная форма  autumn  2023
# 3       Учащийся         Специалитет       Очная форма  autumn  2023
# 4       Учащийся         Специалитет       Очная форма  autumn  2023
# ...          ...                 ...               ...     ...   ...
# 286621  Учащийся         Бакалавриат       Очная форма  spring  2024
# 286622  Учащийся         Бакалавриат       Очная форма  spring  2024
# 286623  Учащийся         Бакалавриат       Очная форма  spring  2024
# 286624  Учащийся         Бакалавриат       Очная форма  spring  2024
# 286625  Учащийся         Бакалавриат       Очная форма  spring  2024
#
#             visit
# 0       88.888889
# 1       16.000000
# 2       50.000000
# 3       31.250000
# 4       88.888889
# ...           ...
# 286621  71.428571
# 286622  57.142857
# 286623  92.307692
# 286624  71.428571
# 286625  76.190476
#
# [286626 rows x 16 columns]

# %%
df = df[df['Форма образования'] == 'Очная форма']

# %%
df = df[df['status'] == 'Учащийся']

# %%
df.isna().sum()
# Out:
# НомерЛД                  0
# ПерваяПопытка            0
# Семестр                  0
# Дисциплина               0
# Кафедра                245
# Тип_Ведомости            0
# ID ЛК                    0
# Иностранец               0
# Курс                     0
# finans                   0
# status                   0
# Уровень образования      0
# Форма образования        0
# Сезон                    0
# Год                      0
# visit                    0
# dtype: int64

# %%
df
# Out:
#         НомерЛД  ПерваяПопытка  Семестр  \
# 5         10119              4        9
# 6         10119              4        9
# 7         10119              2        9
# 8         10119              2        9
# 9         10119              2        9
# ...         ...            ...      ...
# 354379  9960323              4        2
# 354380  9960323              4        2
# 354381  9960323              4        2
# 354382  9960323              2        2
# 354383  9960323              2        2
#
#                                                Дисциплина  Кафедра  \
# 5                 Оптическая связь и обработка информации  каф.ТОР
# 6                 Оптическая связь и обработка информации  каф.ТОР
# 7       Основы автоматизированного проектирования анте...  каф.ТОР
# 8       Основы автоматизированного проектирования анте...  каф.ТОР
# 9       Основы автоматизированного проектирования анте...  каф.ТОР
# ...                                                   ...      ...
# 354379                                   Программирование  каф.АПУ
# 354380                                   Программирование  каф.АПУ
# 354381                                   Программирование  каф.АПУ
# 354382                              Математический анализ   каф.АМ
# 354383                              Математический анализ   каф.АМ
#
#                    Тип_Ведомости     ID ЛК Иностранец  Курс    finans  \
# 5       Дифференцированный зачет  375210.0       True   5.0    Бюджет
# 6       Дифференцированный зачет  375210.0       True   5.0    Бюджет
# 7                        Экзамен  375210.0       True   5.0    Бюджет
# 8                        Экзамен  375210.0       True   5.0    Бюджет
# 9                        Экзамен  375210.0       True   5.0    Бюджет
# ...                          ...       ...        ...   ...       ...
# 354379                   Экзамен  419081.0      False   1.0  Контракт
# 354380                   Экзамен  419081.0      False   1.0  Контракт
# 354381                   Экзамен  419081.0      False   1.0  Контракт
# 354382                   Экзамен  419081.0      False   1.0  Контракт
# 354383                   Экзамен  419081.0      False   1.0  Контракт
#
#           status Уровень образования Форма образования   Сезон     Год  \
# 5       Учащийся         Специалитет       Очная форма  autumn  2023.0
# 6       Учащийся         Специалитет       Очная форма  autumn  2023.0
# 7       Учащийся         Специалитет       Очная форма  autumn  2023.0
# 8       Учащийся         Специалитет       Очная форма  autumn  2023.0
# 9       Учащийся         Специалитет       Очная форма  autumn  2023.0
# ...          ...                 ...               ...     ...     ...
# 354379  Учащийся         Бакалавриат       Очная форма  spring  2024.0
# 354380  Учащийся         Бакалавриат       Очная форма  spring  2024.0
# 354381  Учащийся         Бакалавриат       Очная форма  spring  2024.0
# 354382  Учащийся         Бакалавриат       Очная форма  spring  2024.0
# 354383  Учащийся         Бакалавриат       Очная форма  spring  2024.0
#
#             visit
# 5       88.888889
# 6       16.000000
# 7       50.000000
# 8       31.250000
# 9       88.888889
# ...           ...
# 354379  20.000000
# 354380  66.666667
# 354381  57.142857
# 354382  71.428571
# 354383  76.190476
#
# [289233 rows x 16 columns]

# %%
df[df['visit'].isna()]
# Out:
# Empty DataFrame
# Columns: [НомерЛД, ПерваяПопытка, Семестр, Кафедра, Тип_Ведомости, Иностранец, Курс, finans, status, Уровень образования, Форма образования, Год, visit]
# Index: []

# %%
df.to_csv('dataset.csv', index=False)

# %%
result = df.groupby(
    ['НомерЛД', 'ПерваяПопытка', 'Семестр', 'Дисциплина', 'Кафедра', 
     'Тип_Ведомости', 'ID ЛК', 'Иностранец', 'Курс', 
     'finans', 'status', 'Уровень образования', 'Форма образования', 'Сезон', 'Год'],
    as_index=False
)['visit'].mean()

# %% [markdown]
# **можено делить по**
# - семестрам 1-2, 3-4
# - по сезону осень-весна (179к и 180к)

# %%
df = df[['НомерЛД', 'ПерваяПопытка', 'Семестр', 'Кафедра', 'Тип_Ведомости', 'Иностранец', 'Курс', 'finans', 'status', 'Уровень образования', 'Форма образования', 'Год', 'visit']].copy()

# %%
df['Форма образования'].unique()
# Out:
# array(['Очная форма', 'Очно-заочная', 'Заочная форма'], dtype=object)

# %%
df
# Out:
#         НомерЛД  ПерваяПопытка  Семестр     Кафедра             Тип_Ведомости  \
# 0         10119              4        9     каф.ТОР  Дифференцированный зачет
# 1         10119              4        9     каф.ТОР  Дифференцированный зачет
# 2         10119              2        9     каф.ТОР                   Экзамен
# 3         10119              2        9     каф.ТОР                   Экзамен
# 4         10119              2        9     каф.ТОР                   Экзамен
# ...         ...            ...      ...         ...                       ...
# 286621  9960323              3        2  каф.Физики                   Экзамен
# 286622  9960323              3        2  каф.Физики                   Экзамен
# 286623  9960323              3        2  каф.Физики                   Экзамен
# 286624  9960323              2        2      каф.АМ                   Экзамен
# 286625  9960323              2        2      каф.АМ                   Экзамен
#
#        Иностранец  Курс    finans    status Уровень образования  \
# 0            True   5.0    Бюджет  Учащийся         Специалитет
# 1            True   5.0    Бюджет  Учащийся         Специалитет
# 2            True   5.0    Бюджет  Учащийся         Специалитет
# 3            True   5.0    Бюджет  Учащийся         Специалитет
# 4            True   5.0    Бюджет  Учащийся         Специалитет
# ...           ...   ...       ...       ...                 ...
# 286621      False   1.0  Контракт  Учащийся         Бакалавриат
# 286622      False   1.0  Контракт  Учащийся         Бакалавриат
# 286623      False   1.0  Контракт  Учащийся         Бакалавриат
# 286624      False   1.0  Контракт  Учащийся         Бакалавриат
# 286625      False   1.0  Контракт  Учащийся         Бакалавриат
#
#        Форма образования   Год      visit
# 0            Очная форма  2023  88.888889
# 1            Очная форма  2023  16.000000
# 2            Очная форма  2023  50.000000
# 3            Очная форма  2023  31.250000
# 4            Очная форма  2023  88.888889
# ...                  ...   ...        ...
# 286621       Очная форма  2024  71.428571
# 286622       Очная форма  2024  57.142857
# 286623       Очная форма  2024  92.307692
# 286624       Очная форма  2024  71.428571
# 286625       Очная форма  2024  76.190476
#
# [286626 rows x 13 columns]

# %%
train =

# %%
categorical_features = ['Кафедра', 'Тип_Ведомости', 'finans', 'status', 'Уровень образования', 'Форма образования']
encoder = OneHotEncoder(sparse=False)
X_cat = encoder.fit_transform(data[categorical_features])

# %% [markdown]
# ### делим выборку на тренировочную и тестовую по году - тренировочная 2023 / тестовая 2024
